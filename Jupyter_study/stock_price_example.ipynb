# %% [markdown]
# ## Stock Price Data Processing

# %%
# import libraries
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf

# 
df = yf.download('TSLA', start='2019-01-01', nd='2021-03-21', progress=False)
df.head()

df["Open"].plot()
df["Low"].plot()
plt.show()
